# %% [markdown]
# # start_pakistan_correlations
# ## plotEPCurvesExample.ipynb
# This script plots EP curves generated in Remetrica financial modelling software, showing the effect of increasing correlation on aggregate (AEP) and occurrence (OEP) exceedance probability (or Return period) curves.

# %%
from pathlib import Path
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Set the root path
rootPath = Path('C:/Users/alexa/Documents/02_work/02_start/02_deliv/05_pk_correlation/remetrica/plot')

# %% [markdown]
# ## Load the OEP and AEP curves

# %%
OEP = pd.read_csv(rootPath/'plotExampleOEP_DummyCustomSev.csv')
AEP = pd.read_csv(rootPath/'plotExampleAEP_DummyCustomSev.csv')
OEP=OEP.set_index('RP')
AEP=AEP.set_index('RP')

# %%
OEP
# Out:
#             Risk A        Risk B     A+B (r=0)   A+B (r=0.2)   A+B (r=0.5)  \
# RP
# 2     2.839696e+06  2.842684e+06  3.757864e+06  3.680810e+06  3.546550e+06
# 3     3.504273e+06  3.498659e+06  4.916775e+06  4.808091e+06  4.626549e+06
# 4     4.115826e+06  4.106758e+06  5.926546e+06  5.804013e+06  5.578953e+06
# 5     4.679561e+06  4.674614e+06  6.844709e+06  6.711977e+06  6.442922e+06
# 10    7.098156e+06  7.068779e+06  1.071333e+07  1.054119e+07  1.011180e+07
# 20    1.092350e+07  1.088349e+07  1.668665e+07  1.647352e+07  1.582753e+07
# 25    1.252187e+07  1.256887e+07  1.917342e+07  1.897538e+07  1.823149e+07
# 50    1.932238e+07  1.932337e+07  2.985914e+07  2.954457e+07  2.870262e+07
# 100   2.996767e+07  3.001437e+07  4.606577e+07  4.568719e+07  4.464894e+07
# 200   4.590760e+07  4.643345e+07  7.188868e+07  7.131924e+07  7.023894e+07
# 250   5.330495e+07  5.290414e+07  8.343928e+07  8.306231e+07  8.121459e+07
# 400   7.163557e+07  7.247554e+07  1.102571e+08  1.100841e+08  1.090083e+08
# 500   8.249163e+07  8.432137e+07  1.268616e+08  1.268616e+08  1.239830e+08
# 1000  1.266438e+08  1.269379e+08  2.279340e+08  2.279340e+08  2.225696e+08
#
#        A+B (r=1.0)
# RP
# 2     3.028762e+06
# 3     4.176423e+06
# 4     5.043557e+06
# 5     5.767635e+06
# 10    8.718279e+06
# 20    1.303612e+07
# 25    1.477598e+07
# 50    2.212908e+07
# 100   3.313192e+07
# 200   4.945599e+07
# 250   5.630704e+07
# 400   7.515816e+07
# 500   8.604239e+07
# 1000  1.301955e+08

# %% [markdown]
# ## Plot the EP curves

# %%
colors=[
(68/255,84/255,106/255),    
(254/255,106/255,70/255), 
(133/255,239/255,205/255),
(255/255,192/255,0/255),    
(165/255,165/255,165/255), 
(255/255,193/255,179/255), 
(184/255,193/255,218/255),    
(24/255,186/255,134/255)
]

# %%
plotTitles=['Occurrence Exceedance Probability','Aggregate Exceedance Probability']

fig, axes = plt.subplots(1, 2,figsize=(10,4), constrained_layout=True)

# OEP
ax=axes[0]
ax.set_title(plotTitles[0], fontsize=16)
for i in range(len(OEP.columns)):
    ax.plot(OEP.index, OEP.iloc[:,i], marker='none', linestyle='--', color=colors[i], label=OEP.columns[i])
ax.set_ylabel('Exceedance Probability Loss', fontsize=14)
ax.set_xlabel('Return Period (years)', fontsize=14)
ax.set_xlim(0, 500)
ax.set_ylim(0, 2e8)
ax.tick_params(axis='both',labelsize=14)
ax.legend(loc='upper left')

# AEP
ax=axes[1]
ax.set_title(plotTitles[1], fontsize=16)
for i in range(len(AEP.columns)):
    ax.plot(AEP.index, AEP.iloc[:,i], marker='none', linestyle='--', color=colors[i], label=AEP.columns[i])
ax.set_ylabel('Exceedance Probability Loss', fontsize=14)
ax.set_xlabel('Return Period (years)', fontsize=14)
ax.set_xlim(0, 500)
ax.set_ylim(0, 2e8)
ax.tick_params(axis='both',labelsize=14)
ax.legend(loc='upper left')


plt.show()
