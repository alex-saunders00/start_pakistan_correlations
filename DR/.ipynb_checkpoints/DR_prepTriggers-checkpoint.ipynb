# %% [markdown]
# # start_pakistan_correlations
# ## DR_prepTriggers.ipynb
# This script prepares the data for Pakistan drought, to compute the triggers. It takes the raw data shared by Emily Black (University of Reading), computes the district populations and total Province populations to get the population thresholds. And it computes the 20%ile of the drought variable in each district using the historical data for 2001-2021 (20 years) after linear detrending.

# %%
from pathlib import Path
import os
import sys
import pandas as pd
import numpy as np
from datetime import datetime
from datetime import date, timedelta
import matplotlib.pyplot as plt
from scipy import signal
from scipy import stats

# %%
# Set the root path
rootPath = Path(Path.cwd()/'data')

# %% [markdown]
# ## Load the population data

# %%
popData=pd.read_csv(rootPath/'emily/demographic_updated.csv')

# %%
# Aggregate from District to Province
popProvinces = pd.DataFrame(popData.groupby(by='Province').Rural_population.sum())

# %%
# Threshold = 25% of province rural population
threshold=0.25
popProvinces['Province_threshold']=popProvinces.Rural_population*threshold

# %%
outPath=rootPath/'prep'
outPath.mkdir(exist_ok=True)

# %%
popProvinces.to_csv(outPath/'ProvinceThreshold.csv', index=True)

# %%
distsPunjab = popData.District_id[popData.Province=='Punjab']
distsSindh = popData.District_id[popData.Province=='Sindh']
distsBaloch = popData.District_id[popData.Province=='Balochistan']

# %% [markdown]
# ## Load the historical variables "observed" data

# %%
provinces = list(popProvinces.index.values)
variables=['precip','yield','vhi']
inputFiles=['precip_hc_poi_21_30_init_31.csv',
           'all_yield_model_wheat_date_31_interannual.hea.csv',
           'vhi_hc_poi_21_30_init_31.csv']

# %%
precipData=pd.read_csv(rootPath/('emily/'+inputFiles[0]))
yieldData=pd.read_csv(rootPath/('emily/'+inputFiles[1]))
vhiData=pd.read_csv(rootPath/('emily/'+inputFiles[2]))

# %% [markdown]
# ### Balochistan - precip

# %%
# Pivot the data
precipData=precipData[precipData.District_id.isin(distsBaloch)].pivot(index='District_id', columns='Year', values='Observed_precip')

# %%
# Add the 20th percentile, for only last 20 years
pctile=0.2
yearsStart=2002
yearsEnd=2021
nYears=yearsEnd-yearsStart+1
print(nYears)
precipDataSub = precipData[precipData.columns[np.logical_and(precipData.columns>=yearsStart, precipData.columns<=yearsEnd)]]
precipDataSub['pctile']=precipDataSub.quantile(pctile, axis=1)
# Out:
# 20
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\2693861064.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   precipDataSub['pctile']=precipDataSub.quantile(pctile, axis=1)

# %%
precipDataSub
# Out:
# Year           2002    2003    2004    2005    2006    2007    2008    2009  \
# District_id
# 701           32.94   50.92   41.77   81.79   51.34   75.67   68.10   87.04
# 702           43.81   64.48   44.40  130.33   72.20  145.08   49.36   93.90
# 703           31.34   53.86   40.60  109.99   64.21   79.66   94.31   88.77
# 704           27.94   40.95   30.56   66.12   37.71   91.81   32.31   69.64
# 705           37.16   57.78   54.22   98.13   64.08   84.58   95.33  111.10
# 706           76.28  134.51   93.39  196.51  111.14  225.74  121.95  173.82
# 707           24.13   37.15   24.45   48.59   27.94   67.04   27.62   62.30
# 708           25.30   41.93   28.02   58.95   33.41   69.77   36.44   79.20
# 721           31.53   43.35  ...   67.34   28.79   45.45   44.45   39.60
# 722          100.34  129.80  ...  162.86   91.97  102.62   95.96  166.77
# 723           69.80   51.87  ...   64.45   48.69   59.85   65.35   50.85
# 724          182.03  221.71  ...  273.14  167.36  167.77  172.33  349.79
# 726          170.53  228.57  ...  286.47  158.99  170.52  171.78  321.82
# 727           93.52   95.98  ...  178.40  130.28  121.39  112.94  129.60
# 728           58.38   92.54  ...  138.45   72.12   78.72   80.23  105.47
# 729           66.00   65.77  ...   77.04   54.54   59.58   50.51   74.18
# 730           85.90   96.87  ...  152.17  100.02   98.07   98.67  141.46
# 731          131.94  172.48  ...  227.28  133.30  138.02  136.88  241.93
#
# Year           2018    2019    2020    2021   pctile
# District_id
# 701           42.02  109.35   67.44   31.99   43.500
# 702           63.04  138.71  167.86   68.15   53.640
# 703           45.37  124.99  103.76   36.05   44.690
# 704           38.47  135.80   94.03   50.77   33.742
# 705           52.51  104.91   95.08   40.60   53.878
# 706          121.51  250.03  198.12   92.39  101.790
# 707           29.04   97.47   58.89   30.00   27.812
# 708           33.64  103.12   64.06   30.08   31.744
# 709           57.66  169.92  106.75   51.69   57.172
# 710           63.81  156.59   98.43   52.38   54.580
# 711           49.47  120.49   89.12   40.68   48.850
# 712           45.30  136.01   98.07   44.72   49.046
# 713           48.49  164.58  100.69   43.36   51.538
# 714          148.79  308.39  272.59  124.60  146.000
# 715           99.80  193.17  183.69   79.12   98.318
# 716           52.46  177.60  154.80   69.62   51.824
# 717           32.16   71.50   44.69   24.52   30.276
# 718           80.05  160.05  184.72   71.22   72.452
# 719          108.53  251.94  176.66   92.66   99.484
# 720           82.28  139.17  196.29   69.73   68.458
# 721           30.26   93.15   64.08   30.62   28.620
# 722           75.52  179.92  153.10   63.05   75.382
# 723           37.06  102.31   75.79   29.48   38.884
# 724          170.52  328.70  296.70  140.38  165.768
# 726          155.26  337.47  270.41  139.98  144.692
# 727          120.99  168.23  217.93   80.81   90.706
# 728           71.75  173.02  125.38   59.18   59.020
# 729           37.19  116.11   75.92   31.47   37.942
# 730           95.99  155.19  183.73   66.76   85.302
# 731          136.04  269.34  232.47  109.41  128.312
#
# [30 rows x 21 columns]

# %%
precipDataSub.to_csv(outPath/'precipThreshold.csv', index=True)

# %%
# fig, ax = plt.subplots()
# x=list(precipDataSub.columns[0:-1])
# y=list(precipDataSub[precipDataSub.index==601].values[0][0:-1])
# y_detrend=signal.detrend(y)
# res = stats.linregress(x, y)
# ypred = [res.intercept + res.slope*xi for xi in x]
# ax.plot(x,y)
# ax.plot(x,y_detrend)
# ax.plot(x,ypred)
# plt.show()

# %% [markdown]
# ### Punjab - yield

# %%
# Pivot the data
yieldData=yieldData[yieldData.District_id.isin(distsPunjab)].pivot(index='District_id', columns='Year', values='Obs_yield')

# %%
# Add the 20th percentile, for only last 20 years
pctile=0.2
yearsStart=1983
yearsEnd=2018
nYears=yearsEnd-yearsStart+1
print(nYears)
yieldDataSub = yieldData[yieldData.columns[np.logical_and(yieldData.columns>=yearsStart,yieldData.columns<=yearsEnd)]]
yieldDataSub['pctile']=yieldDataSub.quantile(pctile, axis=1)
# Out:
# 36
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\2972868348.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   
y=np.array(list(yieldDataSub[yieldDataSub.index==601].values[0][0:-1]))
mask = ~np.isnan(x) & ~np.isnan(y)
y_detrend=signal.detrend(y[mask])
res = stats.linregress(x[mask], y[mask])
ypred = [res.intercept + res.slope*xi for xi in x]
ax.plot(x,y, label='data')
ax.plot(x,ypred, label='linear')
ax.plot(x[mask],y_detrend, label='detrended')
ax.legend()
plt.show()

# %% [markdown]
# ### Use the detrended data as the historical dataset and to compute the percentile

# %%
x=np.array(list(yieldDataSub.columns[0:-1]))
detrendedDF=pd.DataFrame(data=[], index=yieldDataSub.columns[0:-1])

for i, distID in enumerate(yieldDataSub.index):
    y=np.array(list(yieldDataSub[yieldDataSub.index==distID].values[0][0:-1]))
    mask = ~np.isnan(x) & ~np.isnan(y)
    y_detrend=signal.detrend(y[mask])
    xy=pd.DataFrame(data=[x[mask], y_detrend])
    xy.columns = xy.iloc[0]
    xy=xy.drop([0])
    
    detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')

detrendedDF.columns=yieldDataSub.index
detrendedDF=detrendedDF.T
detrendedDF['pctile']=detrendedDF.quantile(pctile,axis=1)
# Out:
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')
# C:\Users\alexa\AppData\Local\Temp\ipykernel_24060\639737517.py:12: FutureWarning: Passing 'suffixes' which cause duplicate columns {'1_x'} in the result is deprecated and will raise a MergeError in a future version.
#   detrendedDF=detrendedDF.merge(xy.T, left_index=True, right_index=True, how='outer')

# %%
detrendedDF
# Out:
#                1983.0    1984.0    1985.0    1986.0    1987.0    1988.0  \
# District_id
# 601         -0.056273 -0.196770 -0.158382  0.225751 -0.044217 -0.277134
# 602          0.205970 -0.077717 -0.085580  0.391299 -0.019369 -0.031440

# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Pivot the data
# ----> 2 vhiData=vhiData[precipData.District_id.isin(distsSindh)].pivot(index='District_id', columns='Year', values='Observed_vhi')
#
# File ~\anaconda3\envs\rio38\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'District_id'

# %%
# Add the 20th percentile, for only last 20 years
pctile=0.2
yearsStart=2002
yearsEnd=2021
nYears=yearsEnd-yearsStart+1
print(nYears)
vhiDataSub = vhiData[vhiData.columns[np.logical_and(vhiData.columns>=yearsStart, vhiData.columns<=yearsEnd)]]
vhiDataSub['pctile']=vhiDataSub.quantile(pctile, axis=1)
# Out:
# 20
# C:\Users\alexa\AppData\Local\Temp\ipykernel_11612\2761465090.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vhiDataSub['pctile']=vhiDataSub.quantile(pctile, axis=1)

# %%
vhiDataSub
# Out:
# Year           2002    2003    2004    2005    2006    2007    2008    2009  \
# District_id
# 801          27.374  32.680  48.875  58.060  43.269  66.958  54.217  50.751
# 802          29.730  32.126  49.465  56.916  37.903  55.654  51.067  55.339
# 803          34.907  38.135  52.651  62.602  38.592  60.181  44.366  52.986
# 804          34.790  47.423  59.774  65.124  56.344  72.150  67.066  57.998
# 805          41.304  54.901  58.838  73.209  39.306  63.945  42.493  46.391
# 806          25.698  29.702  50.469  55.148  34.353  57.922  59.739  51.537
# 807          27.843  27.757  42.654  49.906  32.111  52.774  58.237  45.268
# 808          38.389  43.990  53.889  69.561  42.242  65.186  44.176  57.097
# 809          30.757  33.551  54.574  54.881  38.543  52.121  46.078  43.534
# 810          33.183  40.856  49.912  61.750  37.647  57.348  39.665  54.703
# 811          33.976  46.614  57.926  69.538  52.202  66.710  63.429  64.336
# 812          12.837  34.775  69.183  67.358  57.161  71.309  63.248  52.969
# 813          31.288  42.140  56.987  69.585  49.316  67.717  58.015  63.796
# 814          30.212  33.448  64.111  63.529  42.494  56.178  51.065  43.230
# 816          33.102  41.290  58.029  64.006  47.334  63.072  50.807  54.676
# 817          36.089  48.311  55.593  66.961  39.110  59.343  37.615  51.975
# 818          30.355  35.812  47.333  55.494  43.104  55.538  44.152  51.212
# 819          19.042  34.882  57.100  62.918  44.845  62.141  62.397  57.087
# 820          30.436  43.101  49.159  57.686  38.182  64.219  50.706  48.034
# 821          39.155  25.098  63.798  52.706  33.043  64.191  52.162  33.552
# 822          29.326  33.753  46.113  55.801  38.242  49.603  49.565  46.141
# 823          26.144  24.894  66.902  57.264  34.554  65.295  51.978  37.244
#
# Year           2010    2011  ...    2013    2014    2015    2016    2017  \
# District_id                  ...
# 801          48.078  74.871  ...  62.435  53.623  55.019  50.745  44.014
# 802          39.373  54.451  ...  59.210  48.046  47.143  44.045  41.182
